# %%
# Step 1: Environment Setup and Module Import
# ------------------------------------------------------------------------------
# Import the necessary libraries and modules to run the script smoothly.
# Add the project's root path to the system path so Python can find the QuantBT library.
# ------------------------------------------------------------------------------
import sys
import os
import asyncio
from pathlib import Path
from typing import List, Dict, Any
from datetime import datetime

# Set project root path so Python can find the QuantBT library.
# This code reliably finds the root path regardless of script execution location.
try:
    current_dir = Path(os.path.dirname(os.path.realpath(__file__)))
except NameError:
    current_dir = Path.cwd()

project_root = current_dir.parent.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# Import the core components of QuantBT.
import polars as pl
from quantbt.core.interfaces.strategy import TradingStrategy
from quantbt.core.value_objects.backtest_config import BacktestConfig
from quantbt import OrderSide, OrderType
from quantbt import Order
from quantbt.ray.bayesian_parameter_optimizer import BayesianParameterOptimizer
from quantbt.ray.optimization.parameter_space import ParameterSpace

# %%
# Step 2: Define trading strategy
# ------------------------------------------------------------------------------
# Define the trading strategy to optimize.
# In this example, we use 'SimpleSMAStrategy' which uses two Simple Moving Averages (SMA).
#
# You must inherit from the TradingStrategy class and implement the following two core methods:
# 1. _compute_indicators_for_symbol: Pre-compute indicators using Polars in a vectorized manner.
#    This is executed only once before backtesting starts and is very fast.
# 2. generate_signals: Generate trading signals for each time step (row) based on the computed indicators.
# ------------------------------------------------------------------------------
class SimpleSMAStrategy(TradingStrategy):
    """
    Simple Moving Average (SMA) crossover strategy (for Ray optimization)
    - Buy signal: When short-term SMA (buy_sma) crosses above long-term SMA (sell_sma) (simplified as price > buy_sma)
    - Sell signal: When price falls below long-term SMA (sell_sma)
    """
    def __init__(self, buy_sma: int = 15, sell_sma: int = 30, position_size_pct: float = 0.8):
        # Initialize the basic settings of the strategy.
        super().__init__(
            name="SimpleSMAStrategy",
            position_size_pct=position_size_pct,  # Invest 80% of assets at once
            max_positions=1         # Hold a maximum of 1 position
        )
        self.buy_sma = buy_sma
        self.sell_sma = sell_sma
        self.position_size_pct = position_size_pct

    def _compute_indicators_for_symbol(self, symbol_data: pl.DataFrame) -> pl.DataFrame:
        """
        Calculate moving average indicators for each symbol. (Polars vector operations)
        This method is called only once by the backtesting engine after data loading.
        """
        # Sort data chronologically.
        data = symbol_data.sort("timestamp")

        # Use Polars' built-in functions to calculate SMA quickly and efficiently.
        buy_sma_series = self.calculate_sma(data["close"], self.buy_sma)
        sell_sma_series = self.calculate_sma(data["close"], self.sell_sma)

        # Add the calculated indicators as new columns to the dataframe.
        buy_sma_name = f"sma_{self.buy_sma}"
        sell_sma_name = f"sma_{self.sell_sma}"

        # Handle to prevent duplicate column names.
        columns_to_add = [buy_sma_series.alias(buy_sma_name)]
        if sell_sma_name != buy_sma_name:
            columns_to_add.append(sell_sma_series.alias(sell_sma_name))

        return data.with_columns(columns_to_add)

    def generate_signals(self, current_data: Dict[str, Any]) -> List[Order]:
        """
        Generate trading signals based on data from each time step (row).
        This method is called row by row in the backtest loop.
        """
        orders = []
        if not self.broker:
            return orders

        # Extract the necessary values from the current data point.
        symbol = current_data['symbol']
        current_price = current_data['close']
        buy_sma_val = current_data.get(f'sma_{self.buy_sma}')
        sell_sma_val = current_data.get(f'sma_{self.sell_sma}', buy_sma_val)

        # Skip the initial period where indicator values are not yet calculated.
        if buy_sma_val is None or sell_sma_val is None:
            return orders

        # Check the current position status.
        has_position = self.get_current_positions().get(symbol, 0) > 0

        # Buy signal: When current price exceeds 'buy_sma' and there's no position held
        if current_price > buy_sma_val and not has_position:
            portfolio_value = self.get_portfolio_value()
            quantity = self.calculate_position_size(symbol, current_price, portfolio_value)
            if quantity > 0:
                orders.append(Order(symbol, OrderSide.BUY, quantity, OrderType.MARKET))

        # Sell signal: When current price falls below 'sell_sma' and there's a position held
        elif current_price < sell_sma_val and has_position:
            quantity = self.get_current_positions()[symbol]
            orders.append(Order(symbol, OrderSide.SELL, quantity, OrderType.MARKET))

        return orders

# %%
# Step 3: Backtest Environment Configuration (BacktestConfig)
# --------------------------------------------------------------------------
# Set up the basic environment required for backtesting.
# Define which assets to test, for what period, with how much capital, etc.
# --------------------------------------------------------------------------
print("Step 3: Setting up backtest environment...")
config = BacktestConfig(
    symbols=["KRW-BTC"],                  # Target asset for optimization
    start_date=datetime(2024, 1, 1),    # Start date
    end_date=datetime(2024, 3, 31),  # End date
    timeframe="1d",                         # Time frame (daily candles)
    initial_cash=10_000_000,              # Initial capital (10 million KRW)
    commission_rate=0.0,               # Commission fee
    slippage_rate=0.0,                 # Slippage
)
print("✅ Backtest environment setup completed.")
print("-" * 70)
# Out:
# Step 3: Setting up backtest environment...
# ✅ Backtest environment setup completed.
# ----------------------------------------------------------------------

# %%
# Step 4: Define Parameter Search Space (ParameterSpace)
# --------------------------------------------------------------------------
# Define the parameters to optimize and their search ranges.
# The Bayesian optimizer will find the optimal parameter combination within this space.
# Using the from_dict class method allows you to conveniently define the space.
#   - (min_value, max_value) tuple: Integer or Real parameters
#   - [...] list: Categorical parameters
# --------------------------------------------------------------------------
print("Step 4: Defining parameter search space...")
param_config = {
    'buy_sma': (1, 50),   # 'buy_sma' is an integer between 1 and 50
    'sell_sma': (1, 50),   # 'sell_sma' is an integer between 1 and 50
    'position_size_pct': (0.5, 1),   # 'position_size_pct' is a real number between 0.5 and 1
}
param_space = ParameterSpace.from_dict(param_config)
print("✅ Parameter search space definition completed:")
for name, dim in zip(param_space.dimension_names, param_space.dimensions):
    print(f"   - Parameter '{name}': {dim}")
print("-" * 70)
# Out:
# Step 4: Defining parameter search space...
# ✅ Parameter search space definition completed:
#    - Parameter 'buy_sma': Integer(low=1, high=50, prior='uniform', transform='identity')
#    - Parameter 'sell_sma': Integer(low=1, high=50, prior='uniform', transform='identity')
#    - Parameter 'position_size_pct': Real(low=0.5, high=1, prior='uniform', transform='identity')
# ----------------------------------------------------------------------

# %%
# Step 5: Create and Execute Bayesian Optimizer
# --------------------------------------------------------------------------
# Combine all components to create the BayesianParameterOptimizer.
# The optimizer internally sets up a Ray cluster, runs multiple backtests in parallel,
# and uses scikit-optimize to intelligently determine the next parameters to explore.
# --------------------------------------------------------------------------
print("Step 5: Creating Bayesian optimizer and preparing for execution...")
optimizer = BayesianParameterOptimizer(
    strategy_class=SimpleSMAStrategy,    # Strategy class to optimize
    param_space=param_space,             # Defined parameter space
    config=config,                       # Backtest environment configuration
    num_actors=16,                        # Number of CPU cores for parallel execution (Ray actors)
    n_initial_points=16                  # Number of initial random searches (Bayesian optimization starts afterwards)
)
print("✅ Optimizer creation completed.")
print("\n⏳ Starting optimization... (Progress will be displayed in real-time)")

# Execute optimization!
# objective_metric: Target metric for optimization (e.g., 'sharpe_ratio')
# n_iter: Total number of iterations
# early_stopping_patience: Early termination if no performance improvement for N iterations
results = await optimizer.optimize(
    objective_metric='sharpe_ratio',
    n_iter=1000,
    early_stopping_patience=5,
    early_stopping_min_delta=0.01
)
# Out:
# Step 5: Creating Bayesian optimizer and preparing for execution...
# ✅ Optimizer creation completed.
#
# ⏳ Starting optimization... (Progress will be displayed in real-time)
# =============== Bayesian Optimization Progress ===============
# 진행률: 0/1000 (0.0%)
# ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
# --------------------------------------------------------------
# 📊 Current Performance:
#    Total Results: 0
#    Success Rate: 0.0%
#    Average Sharpe Ratio: 0.0000
#    Average Return: 0.0000
#    Average Execution Time: 0.00s
# ==============================================================
# 2025-06-27 17:27:06,711	INFO worker.py:1908 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# Processing... 90/90: 100%|██████████| 90/90 [00:00<00:00]
# =============== Bayesian Optimization Progress ===============
# 진행률: 32/1000 (3.2%), ETA: 1분 17초
# █░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
# --------------------------------------------------------------
# 📊 Current Performance:
#    Total Results: 32
#    Success Rate: 100.0%
#    Average Sharpe Ratio: 10.2677
#    Average Return: 0.4585
#    Average Execution Time: 0.01s
#    Best Sharpe Ratio: 16.3168 (Parameters: {'buy_sma': np.int64(17), 'sell_sma': np.int64(33), 'position_size_pct': 1.0})
# ==============================================================
# Processing... 10/90:  11%|█         | 10/90 [00:00<00:00]
# Processing... 11/90:  12%|█▏        | 11/90 [00:00<00:00]
# Processing... 90/90: 100%|██████████| 90/90 [00:00<00:00] [repeated 31x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# Backtesting Progress:   0%|          | 0/90 [00:00<?]
# Processing... 73/90:  81%|████████  | 73/90 [00:00<00:00]
# Processing... 20/90:  22%|██▏       | 20/90 [00:00<00:00]
# Processing... 38/90:  42%|████▏     | 38/90 [00:00<00:00]
# Processing... 90/90: 100%|██████████| 90/90 [00:00<00:00]
# Processing... 73/90:  81%|████████  | 73/90 [00:00<00:00]
# Processing... 38/90:  42%|████▏     | 38/90 [00:00<00:00]
# Processing... 33/90:  37%|███▋      | 33/90 [00:00<00:00]
# Processing... 58/90:  64%|██████▍   | 58/90 [00:00<00:00]
# Processing... 11/90:  12%|█▏        | 11/90 [00:00<00:00]
# Processing... 12/90:  13%|█▎        | 12/90 [00:00<00:00]
# Processing... 90/90: 100%|██████████| 90/90 [00:00<00:00]
# Processing... 90/90: 100%|██████████| 90/90 [00:00<00:00]
# Processing... 41/90:  46%|████▌     | 41/90 [00:00<00:00]
# Processing... 69/90:  77%|███████▋  | 69/90 [00:00<00:00]
# Processing... 90/90: 100%|██████████| 90/90 [00:00<00:00]
# Processing... 90/90: 100%|██████████| 90/90 [00:00<00:00]
# Processing... 90/90: 100%|██████████| 90/90 [00:00<00:00]
# Processing... 90/90: 100%|██████████| 90/90 [00:00<00:00]
# Processing... 90/90: 100%|██████████| 90/90 [00:00<00:00]
# Processing... 90/90: 100%|██████████| 90/90 [00:00<00:00]
# Processing... 90/90: 100%|██████████| 90/90 [00:00<00:00]
# Processing... 90/90: 100%|██████████| 90/90 [00:00<00:00]
# =============== Bayesian Optimization Progress ===============
# 진행률: 48/1000 (4.8%), ETA: 2분 29초
# ██░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
# --------------------------------------------------------------
# 📊 Current Performance:
#    Total Results: 48
#    Success Rate: 100.0%
#    Average Sharpe Ratio: 11.8285
#    Average Return: 0.5184
#    Average Execution Time: 0.01s
#    Best Sharpe Ratio: 17.7251 (Parameters: {'buy_sma': np.int64(29), 'sell_sma': np.int64(22), 'position_size_pct': 1.0})
# ==============================================================
# =============== Bayesian Optimization Progress ===============
# 진행률: 48/1000 (4.8%), ETA: 4분 9초
# ██░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░
# --------------------------------------------------------------
# 📊 Current Performance:
#    Total Results: 48
#    Success Rate: 100.0%
#    Average Sharpe Ratio: 11.8285
#    Average Return: 0.5184
#    Average Execution Time: 0.01s
#    Best Sharpe Ratio: 17.7251 (Parameters: {'buy_sma': np.int64(29), 'sell_sma': np.int64(22), 'position_size_pct': 1.0})
# ==============================================================
# Processing... 70/90:  78%|███████▊  | 70/90 [00:00<00:00] [repeated 4x across cluster]
# Processing... 90/90: 100%|██████████| 90/90 [00:00<00:00] [repeated 6x across cluster]
# Backtesting Progress:   0%|          | 0/90 [00:00<?]
# =============== Bayesian Optimization Final Result ===============
# 📊 Current Performance:
#    Total Results: 64
#    Success Rate: 100.0%
#    Average Sharpe Ratio: 11.6340
#    Average Return: 0.5199
#    Average Execution Time: 0.01s
#    Best Sharpe Ratio: 17.7251 (Parameters: {'buy_sma': np.int64(29), 'sell_sma': np.int64(22), 'position_size_pct': 1.0})
# ==================================================================

# %%
# Final Results Summary
# The optimize method returns a list of results from all attempts.
# Find and display the best performing result among them.
if results:
    best_result = max(results, key=lambda x: x['result'].get('sharpe_ratio', -999))
    print("🏆 Optimal Performance Parameters and Results:")
    print(f"   - Parameters: {best_result['params']}")
    print(f"   - Sharpe Ratio: {best_result['result']['sharpe_ratio']:.4f}")
    print(f"   - Total Return: {best_result['result']['total_return']:.4f}")
    print(f"   - Maximum Drawdown (MDD): {best_result['result']['max_drawdown']:.4f}")
else:
    print("No results available.")
# Out:
# 🏆 Optimal Performance Parameters and Results:
#    - Parameters: {'buy_sma': np.int64(29), 'sell_sma': np.int64(22), 'position_size_pct': 1.0}
#    - Sharpe Ratio: 17.7251
#    - Total Return: 0.7172
#    - Maximum Drawdown (MDD): 0.1108

# %%
results
# Out:
# [{'params': {'buy_sma': np.int64(12),
#    'sell_sma': np.int64(20),
#    'position_size_pct': 0.9642298795794386},
#   'result': {'sharpe_ratio': 14.422736911207306,
#    'total_return': 0.6363805257421776,
#    'annual_return': 6.379276675519072,
#    'volatility': 0.4423069431823306,
#    'max_drawdown': 0.1099842789745778,
#    'total_trades': 7,
#    'winning_trades': 1,
#    'losing_trades': 2,
#    'win_rate': 0.3333333333333333,
#    'avg_win': 6731188.915534052,
#    'avg_loss': 173640.47008140976,
#    'profit_factor': 19.382546339508856,
#    'final_portfolio_value': 16363805.257421777,
#    'final_equity': 16363805.257421777,
#    'total_pnl': 6363805.257421777,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 63.63805257421776,
#    'annual_return_pct': 637.9276675519071,
#    'volatility_pct': 44.23069431823306,
#    'max_drawdown_pct': 10.99842789745778,
#    'win_rate_pct': 33.33333333333333,
#    'calmar_ratio': 58.00171383578923,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.016227,
#    'duration': 0.016227,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(12),
#     'sell_sma': np.int64(20),
#     'position_size_pct': 0.9642298795794386}},
#   'sharpe_ratio': 14.422736911207306,
#   'calmar_ratio': 58.00171383578923,
#   'total_return': 0.6363805257421776,
#   'annual_return': 6.379276675519072,
#   'max_drawdown': 0.1099842789745778,
#   'volatility': 0.4423069431823306,
#   'win_rate': 0.3333333333333333,
#   'profit_factor': 19.382546339508856,
#   'total_trades': 7,
#   'final_equity': 16363805.257421777,
#   'success': True},
#  {'params': {'buy_sma': np.int64(37),
#    'sell_sma': np.int64(2),
#    'position_size_pct': 0.6700238677825309},
#   'result': {'sharpe_ratio': 6.2507096838481315,
#    'total_return': 0.27360993364813013,
#    'annual_return': 1.6685348350401084,
#    'volatility': 0.2669352632632438,
#    'max_drawdown': 0.08606838249503346,
#    'total_trades': 29,
#    'winning_trades': 10,
#    'losing_trades': 4,
#    'win_rate': 0.7142857142857143,
#    'avg_win': 427545.9407465282,
#    'avg_loss': 384807.0149030722,
#    'profit_factor': 2.7776646746825895,
#    'final_portfolio_value': 12736099.336481301,
#    'final_equity': 12736099.336481301,
#    'total_pnl': 2736099.336481301,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 27.360993364813012,
#    'annual_return_pct': 166.85348350401082,
#    'volatility_pct': 26.69352632632438,
#    'max_drawdown_pct': 8.606838249503346,
#    'win_rate_pct': 71.42857142857143,
#    'calmar_ratio': 19.386153041000746,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.014797,
#    'duration': 0.014797,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(37),
#     'sell_sma': np.int64(2),
#     'position_size_pct': 0.6700238677825309}},
#   'sharpe_ratio': 6.2507096838481315,
#   'calmar_ratio': 19.386153041000746,
#   'total_return': 0.27360993364813013,
#   'annual_return': 1.6685348350401084,
#   'max_drawdown': 0.08606838249503346,
#   'volatility': 0.2669352632632438,
#   'win_rate': 0.7142857142857143,
#   'profit_factor': 2.7776646746825895,
#   'total_trades': 29,
#   'final_equity': 12736099.336481301,
#   'success': True},
#  {'params': {'buy_sma': np.int64(22),
#    'sell_sma': np.int64(19),
#    'position_size_pct': 0.6844909587645124},
#   'result': {'sharpe_ratio': 10.566315828482153,
#    'total_return': 0.4531422052492656,
#    'annual_return': 3.557224674185375,
#    'volatility': 0.3366570460251299,
#    'max_drawdown': 0.08784170398106729,
#    'total_trades': 5,
#    'winning_trades': 1,
#    'losing_trades': 1,
#    'win_rate': 0.5,
#    'avg_win': 4716505.746629196,
#    'avg_loss': 176093.53348008113,
#    'profit_factor': 26.78409396085351,
#    'final_portfolio_value': 14531422.052492656,
#    'final_equity': 14531422.052492656,
#    'total_pnl': 4531422.052492656,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 45.314220524926554,
#    'annual_return_pct': 355.72246741853746,
#    'volatility_pct': 33.66570460251299,
#    'max_drawdown_pct': 8.78417039810673,
#    'win_rate_pct': 50.0,
#    'calmar_ratio': 40.495852345397026,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.015364,
#    'duration': 0.015364,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(22),
#     'sell_sma': np.int64(19),
#     'position_size_pct': 0.6844909587645124}},
#   'sharpe_ratio': 10.566315828482153,
#   'calmar_ratio': 40.495852345397026,
#   'total_return': 0.4531422052492656,
#   'annual_return': 3.557224674185375,
#   'max_drawdown': 0.08784170398106729,
#   'volatility': 0.3366570460251299,
#   'win_rate': 0.5,
#   'profit_factor': 26.78409396085351,
#   'total_trades': 5,
#   'final_equity': 14531422.052492656,
#   'success': True},
#  {'params': {'buy_sma': np.int64(37),
#    'sell_sma': np.int64(47),
#    'position_size_pct': 0.8366395857740916},
#   'result': {'sharpe_ratio': 5.6807727405669715,
#    'total_return': 0.3294037244431632,
#    'annual_return': 2.175710341318591,
#    'volatility': 0.38299549034616787,
#    'max_drawdown': 0.09726564556849637,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 13294037.244431632,
#    'final_equity': 13294037.244431632,
#    'total_pnl': 3294037.2444316316,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 32.94037244431632,
#    'annual_return_pct': 217.5710341318591,
#    'volatility_pct': 38.29954903461679,
#    'max_drawdown_pct': 9.726564556849638,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 22.36874416040773,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.016719,
#    'duration': 0.016719,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(37),
#     'sell_sma': np.int64(47),
#     'position_size_pct': 0.8366395857740916}},
#   'sharpe_ratio': 5.6807727405669715,
#   'calmar_ratio': 22.36874416040773,
#   'total_return': 0.3294037244431632,
#   'annual_return': 2.175710341318591,
#   'max_drawdown': 0.09726564556849637,
#   'volatility': 0.38299549034616787,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 13294037.244431632,
#   'success': True},
#  {'params': {'buy_sma': np.int64(29),
#    'sell_sma': np.int64(24),
#    'position_size_pct': 0.6296951877460272},
#   'result': {'sharpe_ratio': 8.811116006937697,
#    'total_return': 0.3953758801819086,
#    'annual_return': 2.8654954594151794,
#    'volatility': 0.3252136797607642,
#    'max_drawdown': 0.08309612192251502,
#    'total_trades': 3,
#    'winning_trades': 1,
#    'losing_trades': 0,
#    'win_rate': 1.0,
#    'avg_win': 3647860.2355369036,
#    'avg_loss': 0.0,
#    'profit_factor': inf,
#    'final_portfolio_value': 13953758.801819086,
#    'final_equity': 13953758.801819086,
#    'total_pnl': 3953758.801819086,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 39.53758801819086,
#    'annual_return_pct': 286.5495459415179,
#    'volatility_pct': 32.52136797607642,
#    'max_drawdown_pct': 8.309612192251501,
#    'win_rate_pct': 100.0,
#    'calmar_ratio': 34.48410579361549,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.015265,
#    'duration': 0.015265,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(29),
#     'sell_sma': np.int64(24),
#     'position_size_pct': 0.6296951877460272}},
#   'sharpe_ratio': 8.811116006937697,
#   'calmar_ratio': 34.48410579361549,
#   'total_return': 0.3953758801819086,
#   'annual_return': 2.8654954594151794,
#   'max_drawdown': 0.08309612192251502,
#   'volatility': 0.3252136797607642,
#   'win_rate': 1.0,
#   'profit_factor': inf,
#   'total_trades': 3,
#   'final_equity': 13953758.801819086,
#   'success': True},
#  {'params': {'buy_sma': np.int64(19),
#    'sell_sma': np.int64(36),
#    'position_size_pct': 0.8694926662149935},
#   'result': {'sharpe_ratio': 13.819457083886245,
#    'total_return': 0.6038084462940808,
#    'annual_return': 5.801069520223934,
#    'volatility': 0.4197755009484485,
#    'max_drawdown': 0.10244190638200022,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 16038084.462940808,
#    'final_equity': 16038084.462940808,
#    'total_pnl': 6038084.462940808,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 60.38084462940808,
#    'annual_return_pct': 580.1069520223934,
#    'volatility_pct': 41.97755009484485,
#    'max_drawdown_pct': 10.244190638200022,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 56.62789501975945,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.016852,
#    'duration': 0.016852,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(19),
#     'sell_sma': np.int64(36),
#     'position_size_pct': 0.8694926662149935}},
#   'sharpe_ratio': 13.819457083886245,
#   'calmar_ratio': 56.62789501975945,
#   'total_return': 0.6038084462940808,
#   'annual_return': 5.801069520223934,
#   'max_drawdown': 0.10244190638200022,
#   'volatility': 0.4197755009484485,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 16038084.462940808,
#   'success': True},
#  {'params': {'buy_sma': np.int64(4),
#    'sell_sma': np.int64(15),
#    'position_size_pct': 0.7690942581816752},
#   'result': {'sharpe_ratio': 12.52630682410579,
#    'total_return': 0.5443255648438757,
#    'annual_return': 4.833983684620132,
#    'volatility': 0.38590653673894926,
#    'max_drawdown': 0.0976899502673349,
#    'total_trades': 7,
#    'winning_trades': 1,
#    'losing_trades': 2,
#    'win_rate': 0.3333333333333333,
#    'avg_win': 5768696.11200046,
#    'avg_loss': 207681.91828468448,
#    'profit_factor': 13.8882964863915,
#    'final_portfolio_value': 15443255.648438757,
#    'final_equity': 15443255.648438757,
#    'total_pnl': 5443255.648438757,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 54.432556484387575,
#    'annual_return_pct': 483.3983684620132,
#    'volatility_pct': 38.59065367389493,
#    'max_drawdown_pct': 9.76899502673349,
#    'win_rate_pct': 33.33333333333333,
#    'calmar_ratio': 49.48291683424571,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.01431,
#    'duration': 0.01431,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(4),
#     'sell_sma': np.int64(15),
#     'position_size_pct': 0.7690942581816752}},
#   'sharpe_ratio': 12.52630682410579,
#   'calmar_ratio': 49.48291683424571,
#   'total_return': 0.5443255648438757,
#   'annual_return': 4.833983684620132,
#   'max_drawdown': 0.0976899502673349,
#   'volatility': 0.38590653673894926,
#   'win_rate': 0.3333333333333333,
#   'profit_factor': 13.8882964863915,
#   'total_trades': 7,
#   'final_equity': 15443255.648438757,
#   'success': True},
#  {'params': {'buy_sma': np.int64(14),
#    'sell_sma': np.int64(18),
#    'position_size_pct': 0.8871227992501289},
#   'result': {'sharpe_ratio': 14.485606586314557,
#    'total_return': 0.6153660492405894,
#    'annual_return': 6.002174707978916,
#    'volatility': 0.4143543918726565,
#    'max_drawdown': 0.1042018768266059,
#    'total_trades': 5,
#    'winning_trades': 1,
#    'losing_trades': 1,
#    'win_rate': 0.5,
#    'avg_win': 6419585.161221109,
#    'avg_loss': 254680.3001909508,
#    'profit_factor': 25.206445714128336,
#    'final_portfolio_value': 16153660.492405893,
#    'final_equity': 16153660.492405893,
#    'total_pnl': 6153660.492405893,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 61.536604924058935,
#    'annual_return_pct': 600.2174707978916,
#    'volatility_pct': 41.43543918726565,
#    'max_drawdown_pct': 10.42018768266059,
#    'win_rate_pct': 50.0,
#    'calmar_ratio': 57.60140691099701,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.016011,
#    'duration': 0.016011,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(14),
#     'sell_sma': np.int64(18),
#     'position_size_pct': 0.8871227992501289}},
#   'sharpe_ratio': 14.485606586314557,
#   'calmar_ratio': 57.60140691099701,
#   'total_return': 0.6153660492405894,
#   'annual_return': 6.002174707978916,
#   'max_drawdown': 0.1042018768266059,
#   'volatility': 0.4143543918726565,
#   'win_rate': 0.5,
#   'profit_factor': 25.206445714128336,
#   'total_trades': 5,
#   'final_equity': 16153660.492405893,
#   'success': True},
#  {'params': {'buy_sma': np.int64(46),
#    'sell_sma': np.int64(13),
#    'position_size_pct': 0.5300042037889287},
#   'result': {'sharpe_ratio': 5.264584158087549,
#    'total_return': 0.2254492515710473,
#    'annual_return': 1.2820853585227003,
#    'volatility': 0.243530223855029,
#    'max_drawdown': 0.0588775812267467,
#    'total_trades': 9,
#    'winning_trades': 3,
#    'losing_trades': 1,
#    'win_rate': 0.75,
#    'avg_win': 773277.7047351442,
#    'avg_loss': 114185.7868418114,
#    'profit_factor': 20.316303616834908,
#    'final_portfolio_value': 12254492.515710473,
#    'final_equity': 12254492.515710473,
#    'total_pnl': 2254492.515710473,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 22.544925157104732,
#    'annual_return_pct': 128.20853585227005,
#    'volatility_pct': 24.3530223855029,
#    'max_drawdown_pct': 5.88775812267467,
#    'win_rate_pct': 75.0,
#    'calmar_ratio': 21.77544205807624,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.012386,
#    'duration': 0.012386,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(46),
#     'sell_sma': np.int64(13),
#     'position_size_pct': 0.5300042037889287}},
#   'sharpe_ratio': 5.264584158087549,
#   'calmar_ratio': 21.77544205807624,
#   'total_return': 0.2254492515710473,
#   'annual_return': 1.2820853585227003,
#   'max_drawdown': 0.0588775812267467,
#   'volatility': 0.243530223855029,
#   'win_rate': 0.75,
#   'profit_factor': 20.316303616834908,
#   'total_trades': 9,
#   'final_equity': 12254492.515710473,
#   'success': True},
#  {'params': {'buy_sma': np.int64(4),
#    'sell_sma': np.int64(25),
#    'position_size_pct': 0.941667055452835},
#   'result': {'sharpe_ratio': 13.147656337319034,
#    'total_return': 0.6018026241498126,
#    'annual_return': 5.766615952706452,
#    'volatility': 0.4386040983090021,
#    'max_drawdown': 0.1070738054658538,
#    'total_trades': 7,
#    'winning_trades': 3,
#    'losing_trades': 0,
#    'win_rate': 1.0,
#    'avg_win': 1967026.0938760403,
#    'avg_loss': 0.0,
#    'profit_factor': inf,
#    'final_portfolio_value': 16018026.241498126,
#    'final_equity': 16018026.241498126,
#    'total_pnl': 6018026.241498126,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 60.18026241498126,
#    'annual_return_pct': 576.6615952706452,
#    'volatility_pct': 43.86040983090021,
#    'max_drawdown_pct': 10.70738054658538,
#    'win_rate_pct': 100.0,
#    'calmar_ratio': 53.85645842713086,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.013615,
#    'duration': 0.013615,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(4),
#     'sell_sma': np.int64(25),
#     'position_size_pct': 0.941667055452835}},
#   'sharpe_ratio': 13.147656337319034,
#   'calmar_ratio': 53.85645842713086,
#   'total_return': 0.6018026241498126,
#   'annual_return': 5.766615952706452,
#   'max_drawdown': 0.1070738054658538,
#   'volatility': 0.4386040983090021,
#   'win_rate': 1.0,
#   'profit_factor': inf,
#   'total_trades': 7,
#   'final_equity': 16018026.241498126,
#   'success': True},
#  {'params': {'buy_sma': np.int64(29),
#    'sell_sma': np.int64(23),
#    'position_size_pct': 0.8908617419620545},
#   'result': {'sharpe_ratio': 15.164854393329323,
#    'total_return': 0.6293743590446949,
#    'annual_return': 6.25189312793608,
#    'volatility': 0.412261995122495,
#    'max_drawdown': 0.10362922803967038,
#    'total_trades': 5,
#    'winning_trades': 1,
#    'losing_trades': 1,
#    'win_rate': 0.5,
#    'avg_win': 6129879.005154107,
#    'avg_loss': 336085.6060903608,
#    'profit_factor': 18.23904057202025,
#    'final_portfolio_value': 16293743.590446949,
#    'final_equity': 16293743.590446949,
#    'total_pnl': 6293743.590446949,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 62.93743590446949,
#    'annual_return_pct': 625.189312793608,
#    'volatility_pct': 41.2261995122495,
#    'max_drawdown_pct': 10.362922803967038,
#    'win_rate_pct': 50.0,
#    'calmar_ratio': 60.32943838530562,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.015743,
#    'duration': 0.015743,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(29),
#     'sell_sma': np.int64(23),
#     'position_size_pct': 0.8908617419620545}},
#   'sharpe_ratio': 15.164854393329323,
#   'calmar_ratio': 60.32943838530562,
#   'total_return': 0.6293743590446949,
#   'annual_return': 6.25189312793608,
#   'max_drawdown': 0.10362922803967038,
#   'volatility': 0.412261995122495,
#   'win_rate': 0.5,
#   'profit_factor': 18.23904057202025,
#   'total_trades': 5,
#   'final_equity': 16293743.590446949,
#   'success': True},
#  {'params': {'buy_sma': np.int64(43),
#    'sell_sma': np.int64(16),
#    'position_size_pct': 0.5831070386644044},
#   'result': {'sharpe_ratio': 6.67444175466301,
#    'total_return': 0.29916952134015634,
#    'annual_return': 1.8926360877885116,
#    'volatility': 0.2835647020915639,
#    'max_drawdown': 0.07614508791284184,
#    'total_trades': 7,
#    'winning_trades': 2,
#    'losing_trades': 1,
#    'win_rate': 0.6666666666666666,
#    'avg_win': 1535249.7883849328,
#    'avg_loss': 134955.79180668225,
#    'profit_factor': 22.751891828164073,
#    'final_portfolio_value': 12991695.213401563,
#    'final_equity': 12991695.213401563,
#    'total_pnl': 2991695.2134015635,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 29.916952134015634,
#    'annual_return_pct': 189.26360877885116,
#    'volatility_pct': 28.35647020915639,
#    'max_drawdown_pct': 7.614508791284185,
#    'win_rate_pct': 66.66666666666666,
#    'calmar_ratio': 24.85565569186662,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.014182,
#    'duration': 0.014182,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(43),
#     'sell_sma': np.int64(16),
#     'position_size_pct': 0.5831070386644044}},
#   'sharpe_ratio': 6.67444175466301,
#   'calmar_ratio': 24.85565569186662,
#   'total_return': 0.29916952134015634,
#   'annual_return': 1.8926360877885116,
#   'max_drawdown': 0.07614508791284184,
#   'volatility': 0.2835647020915639,
#   'win_rate': 0.6666666666666666,
#   'profit_factor': 22.751891828164073,
#   'total_trades': 7,
#   'final_equity': 12991695.213401563,
#   'success': True},
#  {'params': {'buy_sma': np.int64(1),
#    'sell_sma': np.int64(37),
#    'position_size_pct': 0.5910982991321606},
#   'result': {'sharpe_ratio': 0.0,
#    'total_return': 0.0,
#    'annual_return': 0.0,
#    'volatility': 0.0,
#    'max_drawdown': 0.0,
#    'total_trades': 0,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 10000000.0,
#    'final_equity': 10000000.0,
#    'total_pnl': 0.0,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 0.0,
#    'annual_return_pct': 0.0,
#    'volatility_pct': 0.0,
#    'max_drawdown_pct': 0.0,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 0.0,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.012471,
#    'duration': 0.012471,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(1),
#     'sell_sma': np.int64(37),
#     'position_size_pct': 0.5910982991321606}},
#   'sharpe_ratio': 0.0,
#   'calmar_ratio': 0.0,
#   'total_return': 0.0,
#   'annual_return': 0.0,
#   'max_drawdown': 0.0,
#   'volatility': 0.0,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 0,
#   'final_equity': 10000000.0,
#   'success': True},
#  {'params': {'buy_sma': np.int64(21),
#    'sell_sma': np.int64(3),
#    'position_size_pct': 0.8670823924790079},
#   'result': {'sharpe_ratio': 9.436269643322433,
#    'total_return': 0.43420494710219426,
#    'annual_return': 3.320962717592276,
#    'volatility': 0.35193597079353833,
#    'max_drawdown': 0.058352864960283975,
#    'total_trades': 25,
#    'winning_trades': 7,
#    'losing_trades': 5,
#    'win_rate': 0.5833333333333334,
#    'avg_win': 727778.9291775873,
#    'avg_loss': 150268.74010680645,
#    'profit_factor': 6.780455470142531,
#    'final_portfolio_value': 14342049.471021943,
#    'final_equity': 14342049.471021943,
#    'total_pnl': 4342049.471021943,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 43.42049471021943,
#    'annual_return_pct': 332.0962717592276,
#    'volatility_pct': 35.193597079353836,
#    'max_drawdown_pct': 5.835286496028398,
#    'win_rate_pct': 58.333333333333336,
#    'calmar_ratio': 56.911733808658475,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.011338,
#    'duration': 0.011338,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(21),
#     'sell_sma': np.int64(3),
#     'position_size_pct': 0.8670823924790079}},
#   'sharpe_ratio': 9.436269643322433,
#   'calmar_ratio': 56.911733808658475,
#   'total_return': 0.43420494710219426,
#   'annual_return': 3.320962717592276,
#   'max_drawdown': 0.058352864960283975,
#   'volatility': 0.35193597079353833,
#   'win_rate': 0.5833333333333334,
#   'profit_factor': 6.780455470142531,
#   'total_trades': 25,
#   'final_equity': 14342049.471021943,
#   'success': True},
#  {'params': {'buy_sma': np.int64(44),
#    'sell_sma': np.int64(8),
#    'position_size_pct': 0.6976421552942408},
#   'result': {'sharpe_ratio': 3.07906705181242,
#    'total_return': 0.17761153357165196,
#    'annual_return': 0.9415562994019966,
#    'volatility': 0.3057927234315251,
#    'max_drawdown': 0.11809576103473508,
#    'total_trades': 13,
#    'winning_trades': 4,
#    'losing_trades': 2,
#    'win_rate': 0.6666666666666666,
#    'avg_win': 706697.7191399373,
#    'avg_loss': 555542.6415847919,
#    'profit_factor': 2.544170928531954,
#    'final_portfolio_value': 11776115.33571652,
#    'final_equity': 11776115.33571652,
#    'total_pnl': 1776115.3357165195,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 17.761153357165195,
#    'annual_return_pct': 94.15562994019966,
#    'volatility_pct': 30.579272343152507,
#    'max_drawdown_pct': 11.809576103473509,
#    'win_rate_pct': 66.66666666666666,
#    'calmar_ratio': 7.972820456485818,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.017526,
#    'duration': 0.017526,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(44),
#     'sell_sma': np.int64(8),
#     'position_size_pct': 0.6976421552942408}},
#   'sharpe_ratio': 3.07906705181242,
#   'calmar_ratio': 7.972820456485818,
#   'total_return': 0.17761153357165196,
#   'annual_return': 0.9415562994019966,
#   'max_drawdown': 0.11809576103473508,
#   'volatility': 0.3057927234315251,
#   'win_rate': 0.6666666666666666,
#   'profit_factor': 2.544170928531954,
#   'total_trades': 13,
#   'final_equity': 11776115.33571652,
#   'success': True},
#  {'params': {'buy_sma': np.int64(40),
#    'sell_sma': np.int64(36),
#    'position_size_pct': 0.8880775766680867},
#   'result': {'sharpe_ratio': 9.693360013652137,
#    'total_return': 0.49348171608366015,
#    'annual_return': 4.092854888741833,
#    'volatility': 0.4222328359802434,
#    'max_drawdown': 0.10383782991681476,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 14934817.160836602,
#    'final_equity': 14934817.160836602,
#    'total_pnl': 4934817.160836602,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 49.348171608366016,
#    'annual_return_pct': 409.28548887418333,
#    'volatility_pct': 42.22328359802434,
#    'max_drawdown_pct': 10.383782991681475,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 39.4158361362198,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.019178,
#    'duration': 0.019178,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(40),
#     'sell_sma': np.int64(36),
#     'position_size_pct': 0.8880775766680867}},
#   'sharpe_ratio': 9.693360013652137,
#   'calmar_ratio': 39.4158361362198,
#   'total_return': 0.49348171608366015,
#   'annual_return': 4.092854888741833,
#   'max_drawdown': 0.10383782991681476,
#   'volatility': 0.4222328359802434,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 14934817.160836602,
#   'success': True},
#  {'params': {'buy_sma': np.int64(22),
#    'sell_sma': np.int64(28),
#    'position_size_pct': 0.9502242284100807},
#   'result': {'sharpe_ratio': 15.23875007221977,
#    'total_return': 0.65879445996555,
#    'annual_return': 6.798149171187014,
#    'volatility': 0.4461093684829201,
#    'max_drawdown': 0.1076332264778443,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 16587944.5996555,
#    'final_equity': 16587944.5996555,
#    'total_pnl': 6587944.5996555,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 65.87944599655499,
#    'annual_return_pct': 679.8149171187015,
#    'volatility_pct': 44.61093684829201,
#    'max_drawdown_pct': 10.763322647784431,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 63.16032133986409,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.011744,
#    'duration': 0.011744,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(22),
#     'sell_sma': np.int64(28),
#     'position_size_pct': 0.9502242284100807}},
#   'sharpe_ratio': 15.23875007221977,
#   'calmar_ratio': 63.16032133986409,
#   'total_return': 0.65879445996555,
#   'annual_return': 6.798149171187014,
#   'max_drawdown': 0.1076332264778443,
#   'volatility': 0.4461093684829201,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 16587944.5996555,
#   'success': True},
#  {'params': {'buy_sma': np.int64(1),
#    'sell_sma': np.int64(1),
#    'position_size_pct': 0.5},
#   'result': {'sharpe_ratio': 0.0,
#    'total_return': 0.0,
#    'annual_return': 0.0,
#    'volatility': 0.0,
#    'max_drawdown': 0.0,
#    'total_trades': 0,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 10000000.0,
#    'final_equity': 10000000.0,
#    'total_pnl': 0.0,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 0.0,
#    'annual_return_pct': 0.0,
#    'volatility_pct': 0.0,
#    'max_drawdown_pct': 0.0,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 0.0,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.01491,
#    'duration': 0.01491,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(1),
#     'sell_sma': np.int64(1),
#     'position_size_pct': 0.5}},
#   'sharpe_ratio': 0.0,
#   'calmar_ratio': 0.0,
#   'total_return': 0.0,
#   'annual_return': 0.0,
#   'max_drawdown': 0.0,
#   'volatility': 0.0,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 0,
#   'final_equity': 10000000.0,
#   'success': True},
#  {'params': {'buy_sma': np.int64(28),
#    'sell_sma': np.int64(23),
#    'position_size_pct': 0.8978090108104715},
#   'result': {'sharpe_ratio': 15.205364578235784,
#    'total_return': 0.6323996870145153,
#    'annual_return': 6.306693510926393,
#    'volatility': 0.4147676616681382,
#    'max_drawdown': 0.10411243844007118,
#    'total_trades': 5,
#    'winning_trades': 1,
#    'losing_trades': 1,
#    'win_rate': 0.5,
#    'avg_win': 6178171.45501497,
#    'avg_loss': 353968.6593258518,
#    'profit_factor': 17.45400699254436,
#    'final_portfolio_value': 16323996.870145153,
#    'final_equity': 16323996.870145153,
#    'total_pnl': 6323996.870145153,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 63.23996870145153,
#    'annual_return_pct': 630.6693510926393,
#    'volatility_pct': 41.476766166813825,
#    'max_drawdown_pct': 10.411243844007117,
#    'win_rate_pct': 50.0,
#    'calmar_ratio': 60.5757929160081,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.010524,
#    'duration': 0.010524,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(28),
#     'sell_sma': np.int64(23),
#     'position_size_pct': 0.8978090108104715}},
#   'sharpe_ratio': 15.205364578235784,
#   'calmar_ratio': 60.5757929160081,
#   'total_return': 0.6323996870145153,
#   'annual_return': 6.306693510926393,
#   'max_drawdown': 0.10411243844007118,
#   'volatility': 0.4147676616681382,
#   'win_rate': 0.5,
#   'profit_factor': 17.45400699254436,
#   'total_trades': 5,
#   'final_equity': 16323996.870145153,
#   'success': True},
#  {'params': {'buy_sma': np.int64(12),
#    'sell_sma': np.int64(37),
#    'position_size_pct': 1.0},
#   'result': {'sharpe_ratio': 6.400500567381936,
#    'total_return': 0.39354680061497055,
#    'annual_return': 2.844973271681464,
#    'volatility': 0.44449230833287356,
#    'max_drawdown': 0.11036710871650235,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 13935468.006149705,
#    'final_equity': 13935468.006149705,
#    'total_pnl': 3935468.0061497055,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 39.354680061497056,
#    'annual_return_pct': 284.4973271681464,
#    'volatility_pct': 44.44923083328736,
#    'max_drawdown_pct': 11.036710871650236,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 25.777365238309237,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.012698,
#    'duration': 0.012698,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(12),
#     'sell_sma': np.int64(37),
#     'position_size_pct': 1.0}},
#   'sharpe_ratio': 6.400500567381936,
#   'calmar_ratio': 25.777365238309237,
#   'total_return': 0.39354680061497055,
#   'annual_return': 2.844973271681464,
#   'max_drawdown': 0.11036710871650235,
#   'volatility': 0.44449230833287356,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 13935468.006149705,
#   'success': True},
#  {'params': {'buy_sma': np.int64(1),
#    'sell_sma': np.int64(1),
#    'position_size_pct': 0.6458478591094561},
#   'result': {'sharpe_ratio': 0.0,
#    'total_return': 0.0,
#    'annual_return': 0.0,
#    'volatility': 0.0,
#    'max_drawdown': 0.0,
#    'total_trades': 0,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 10000000.0,
#    'final_equity': 10000000.0,
#    'total_pnl': 0.0,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 0.0,
#    'annual_return_pct': 0.0,
#    'volatility_pct': 0.0,
#    'max_drawdown_pct': 0.0,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 0.0,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.013886,
#    'duration': 0.013886,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(1),
#     'sell_sma': np.int64(1),
#     'position_size_pct': 0.6458478591094561}},
#   'sharpe_ratio': 0.0,
#   'calmar_ratio': 0.0,
#   'total_return': 0.0,
#   'annual_return': 0.0,
#   'max_drawdown': 0.0,
#   'volatility': 0.0,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 0,
#   'final_equity': 10000000.0,
#   'success': True},
#  {'params': {'buy_sma': np.int64(27),
#    'sell_sma': np.int64(23),
#    'position_size_pct': 0.9042518438802251},
#   'result': {'sharpe_ratio': 13.803927733470497,
#    'total_return': 0.5993543881211418,
#    'annual_return': 5.724741575073148,
#    'volatility': 0.41471830957158085,
#    'max_drawdown': 0.10451384120157824,
#    'total_trades': 5,
#    'winning_trades': 1,
#    'losing_trades': 1,
#    'win_rate': 0.5,
#    'avg_win': 6224764.045435657,
#    'avg_loss': 347110.70713938895,
#    'profit_factor': 17.933079900459493,
#    'final_portfolio_value': 15993543.881211419,
#    'final_equity': 15993543.881211419,
#    'total_pnl': 5993543.881211419,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 59.935438812114185,
#    'annual_return_pct': 572.4741575073148,
#    'volatility_pct': 41.47183095715808,
#    'max_drawdown_pct': 10.451384120157824,
#    'win_rate_pct': 50.0,
#    'calmar_ratio': 54.7749609932689,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.010974,
#    'duration': 0.010974,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(27),
#     'sell_sma': np.int64(23),
#     'position_size_pct': 0.9042518438802251}},
#   'sharpe_ratio': 13.803927733470497,
#   'calmar_ratio': 54.7749609932689,
#   'total_return': 0.5993543881211418,
#   'annual_return': 5.724741575073148,
#   'max_drawdown': 0.10451384120157824,
#   'volatility': 0.41471830957158085,
#   'win_rate': 0.5,
#   'profit_factor': 17.933079900459493,
#   'total_trades': 5,
#   'final_equity': 15993543.881211419,
#   'success': True},
#  {'params': {'buy_sma': np.int64(17),
#    'sell_sma': np.int64(33),
#    'position_size_pct': 1.0},
#   'result': {'sharpe_ratio': 16.316771987758866,
#    'total_return': 0.6945111228850659,
#    'annual_return': 7.502342984294765,
#    'volatility': 0.45979333350512935,
#    'max_drawdown': 0.11046951739325007,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 16945111.22885066,
#    'final_equity': 16945111.22885066,
#    'total_pnl': 6945111.228850659,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 69.4511122885066,
#    'annual_return_pct': 750.2342984294766,
#    'volatility_pct': 45.97933335051294,
#    'max_drawdown_pct': 11.046951739325008,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 67.91324123910017,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.011147,
#    'duration': 0.011147,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(17),
#     'sell_sma': np.int64(33),
#     'position_size_pct': 1.0}},
#   'sharpe_ratio': 16.316771987758866,
#   'calmar_ratio': 67.91324123910017,
#   'total_return': 0.6945111228850659,
#   'annual_return': 7.502342984294765,
#   'max_drawdown': 0.11046951739325007,
#   'volatility': 0.45979333350512935,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 16945111.22885066,
#   'success': True},
#  {'params': {'buy_sma': np.int64(15),
#    'sell_sma': np.int64(34),
#    'position_size_pct': 0.9936900927698064},
#   'result': {'sharpe_ratio': 16.160366746700095,
#    'total_return': 0.6895337611328579,
#    'annual_return': 7.401443265866609,
#    'volatility': 0.4579997089099456,
#    'max_drawdown': 0.1101105914875829,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 16895337.61132858,
#    'final_equity': 16895337.61132858,
#    'total_pnl': 6895337.6113285795,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 68.95337611328578,
#    'annual_return_pct': 740.1443265866609,
#    'volatility_pct': 45.799970890994565,
#    'max_drawdown_pct': 11.01105914875829,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 67.21826815998227,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.012861,
#    'duration': 0.012861,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(15),
#     'sell_sma': np.int64(34),
#     'position_size_pct': 0.9936900927698064}},
#   'sharpe_ratio': 16.160366746700095,
#   'calmar_ratio': 67.21826815998227,
#   'total_return': 0.6895337611328579,
#   'annual_return': 7.401443265866609,
#   'max_drawdown': 0.1101105914875829,
#   'volatility': 0.4579997089099456,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 16895337.61132858,
#   'success': True},
#  {'params': {'buy_sma': np.int64(28),
#    'sell_sma': np.int64(24),
#    'position_size_pct': 0.8998112403518875},
#   'result': {'sharpe_ratio': 12.314112566694694,
#    'total_return': 0.570110307920922,
#    'annual_return': 5.23950186373882,
#    'volatility': 0.42548757251982683,
#    'max_drawdown': 0.10423565240521156,
#    'total_trades': 3,
#    'winning_trades': 1,
#    'losing_trades': 0,
#    'win_rate': 1.0,
#    'avg_win': 5217131.823004313,
#    'avg_loss': 0.0,
#    'profit_factor': inf,
#    'final_portfolio_value': 15701103.07920922,
#    'final_equity': 15701103.07920922,
#    'total_pnl': 5701103.07920922,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 57.0110307920922,
#    'annual_return_pct': 523.9501863738819,
#    'volatility_pct': 42.548757251982686,
#    'max_drawdown_pct': 10.423565240521155,
#    'win_rate_pct': 100.0,
#    'calmar_ratio': 50.26592862267974,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.01124,
#    'duration': 0.01124,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(28),
#     'sell_sma': np.int64(24),
#     'position_size_pct': 0.8998112403518875}},
#   'sharpe_ratio': 12.314112566694694,
#   'calmar_ratio': 50.26592862267974,
#   'total_return': 0.570110307920922,
#   'annual_return': 5.23950186373882,
#   'max_drawdown': 0.10423565240521156,
#   'volatility': 0.42548757251982683,
#   'win_rate': 1.0,
#   'profit_factor': inf,
#   'total_trades': 3,
#   'final_equity': 15701103.07920922,
#   'success': True},
#  {'params': {'buy_sma': np.int64(20),
#    'sell_sma': np.int64(31),
#    'position_size_pct': 0.9664661115655951},
#   'result': {'sharpe_ratio': 15.529249568937795,
#    'total_return': 0.6718684366008686,
#    'annual_return': 7.050604977594329,
#    'volatility': 0.45402097160555793,
#    'max_drawdown': 0.10922339845034075,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 16718684.366008686,
#    'final_equity': 16718684.366008686,
#    'total_pnl': 6718684.366008686,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 67.18684366008686,
#    'annual_return_pct': 705.0604977594329,
#    'volatility_pct': 45.40209716055579,
#    'max_drawdown_pct': 10.922339845034076,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 64.55214796122591,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.011717,
#    'duration': 0.011717,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(20),
#     'sell_sma': np.int64(31),
#     'position_size_pct': 0.9664661115655951}},
#   'sharpe_ratio': 15.529249568937795,
#   'calmar_ratio': 64.55214796122591,
#   'total_return': 0.6718684366008686,
#   'annual_return': 7.050604977594329,
#   'max_drawdown': 0.10922339845034075,
#   'volatility': 0.45402097160555793,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 16718684.366008686,
#   'success': True},
#  {'params': {'buy_sma': np.int64(1),
#    'sell_sma': np.int64(1),
#    'position_size_pct': 0.6116352599602136},
#   'result': {'sharpe_ratio': 0.0,
#    'total_return': 0.0,
#    'annual_return': 0.0,
#    'volatility': 0.0,
#    'max_drawdown': 0.0,
#    'total_trades': 0,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 10000000.0,
#    'final_equity': 10000000.0,
#    'total_pnl': 0.0,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 0.0,
#    'annual_return_pct': 0.0,
#    'volatility_pct': 0.0,
#    'max_drawdown_pct': 0.0,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 0.0,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.012025,
#    'duration': 0.012025,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(1),
#     'sell_sma': np.int64(1),
#     'position_size_pct': 0.6116352599602136}},
#   'sharpe_ratio': 0.0,
#   'calmar_ratio': 0.0,
#   'total_return': 0.0,
#   'annual_return': 0.0,
#   'max_drawdown': 0.0,
#   'volatility': 0.0,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 0,
#   'final_equity': 10000000.0,
#   'success': True},
#  {'params': {'buy_sma': np.int64(14),
#    'sell_sma': np.int64(36),
#    'position_size_pct': 1.0},
#   'result': {'sharpe_ratio': 6.424832774794159,
#    'total_return': 0.3943289298835827,
#    'annual_return': 2.853738651409941,
#    'volatility': 0.44417321842300717,
#    'max_drawdown': 0.11030764586581651,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 13943289.298835827,
#    'final_equity': 13943289.298835827,
#    'total_pnl': 3943289.298835827,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 39.43289298835827,
#    'annual_return_pct': 285.3738651409941,
#    'volatility_pct': 44.417321842300716,
#    'max_drawdown_pct': 11.03076458658165,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 25.87072391048364,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.010512,
#    'duration': 0.010512,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(14),
#     'sell_sma': np.int64(36),
#     'position_size_pct': 1.0}},
#   'sharpe_ratio': 6.424832774794159,
#   'calmar_ratio': 25.87072391048364,
#   'total_return': 0.3943289298835827,
#   'annual_return': 2.853738651409941,
#   'max_drawdown': 0.11030764586581651,
#   'volatility': 0.44417321842300717,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 13943289.298835827,
#   'success': True},
#  {'params': {'buy_sma': np.int64(28),
#    'sell_sma': np.int64(23),
#    'position_size_pct': 0.9039365299309383},
#   'result': {'sharpe_ratio': 15.429644791700499,
#    'total_return': 0.6391818583205509,
#    'annual_return': 6.430678509949889,
#    'volatility': 0.4167742418418412,
#    'max_drawdown': 0.10449203476101375,
#    'total_trades': 5,
#    'winning_trades': 1,
#    'losing_trades': 1,
#    'win_rate': 0.5,
#    'avg_win': 6232396.811556044,
#    'avg_loss': 353311.25960883923,
#    'profit_factor': 17.639960918472013,
#    'final_portfolio_value': 16391818.583205508,
#    'final_equity': 16391818.583205508,
#    'total_pnl': 6391818.583205508,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 63.91818583205509,
#    'annual_return_pct': 643.0678509949889,
#    'volatility_pct': 41.67742418418412,
#    'max_drawdown_pct': 10.449203476101374,
#    'win_rate_pct': 50.0,
#    'calmar_ratio': 61.54228429619204,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.011045,
#    'duration': 0.011045,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(28),
#     'sell_sma': np.int64(23),
#     'position_size_pct': 0.9039365299309383}},
#   'sharpe_ratio': 15.429644791700499,
#   'calmar_ratio': 61.54228429619204,
#   'total_return': 0.6391818583205509,
#   'annual_return': 6.430678509949889,
#   'max_drawdown': 0.10449203476101375,
#   'volatility': 0.4167742418418412,
#   'win_rate': 0.5,
#   'profit_factor': 17.639960918472013,
#   'total_trades': 5,
#   'final_equity': 16391818.583205508,
#   'success': True},
#  {'params': {'buy_sma': np.int64(20),
#    'sell_sma': np.int64(30),
#    'position_size_pct': 0.9691899472640668},
#   'result': {'sharpe_ratio': 15.837371032819073,
#    'total_return': 0.6771093248738697,
#    'annual_return': 7.153515630935493,
#    'volatility': 0.4516858016467243,
#    'max_drawdown': 0.10878631998270938,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 16771093.248738697,
#    'final_equity': 16771093.248738697,
#    'total_pnl': 6771093.248738697,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 67.71093248738697,
#    'annual_return_pct': 715.3515630935493,
#    'volatility_pct': 45.16858016467243,
#    'max_drawdown_pct': 10.878631998270938,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 65.75749259716186,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.011668,
#    'duration': 0.011668,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(20),
#     'sell_sma': np.int64(30),
#     'position_size_pct': 0.9691899472640668}},
#   'sharpe_ratio': 15.837371032819073,
#   'calmar_ratio': 65.75749259716186,
#   'total_return': 0.6771093248738697,
#   'annual_return': 7.153515630935493,
#   'max_drawdown': 0.10878631998270938,
#   'volatility': 0.4516858016467243,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 16771093.248738697,
#   'success': True},
#  {'params': {'buy_sma': np.int64(18),
#    'sell_sma': np.int64(32),
#    'position_size_pct': 0.982572219975113},
#   'result': {'sharpe_ratio': 15.561608179717059,
#    'total_return': 0.6757719848776224,
#    'annual_return': 7.127161816446627,
#    'volatility': 0.457996483020061,
#    'max_drawdown': 0.10998216420331995,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 16757719.848776223,
#    'final_equity': 16757719.848776223,
#    'total_pnl': 6757719.848776223,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 67.57719848776223,
#    'annual_return_pct': 712.7161816446627,
#    'volatility_pct': 45.799648302006105,
#    'max_drawdown_pct': 10.998216420331994,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 64.80288752338886,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.010827,
#    'duration': 0.010827,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(18),
#     'sell_sma': np.int64(32),
#     'position_size_pct': 0.982572219975113}},
#   'sharpe_ratio': 15.561608179717059,
#   'calmar_ratio': 64.80288752338886,
#   'total_return': 0.6757719848776224,
#   'annual_return': 7.127161816446627,
#   'max_drawdown': 0.10998216420331995,
#   'volatility': 0.457996483020061,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 16757719.848776223,
#   'success': True},
#  {'params': {'buy_sma': np.int64(22),
#    'sell_sma': np.int64(29),
#    'position_size_pct': 0.9542761219100115},
#   'result': {'sharpe_ratio': 15.321608766935116,
#    'total_return': 0.6617552958049014,
#    'annual_return': 6.854792168863001,
#    'volatility': 0.4473937608729459,
#    'max_drawdown': 0.1078893030357921,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 16617552.958049014,
#    'final_equity': 16617552.958049014,
#    'total_pnl': 6617552.958049014,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 66.17552958049015,
#    'annual_return_pct': 685.4792168863,
#    'volatility_pct': 44.73937608729459,
#    'max_drawdown_pct': 10.78893030357921,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 63.53541987928993,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.008729,
#    'duration': 0.008729,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
# ...
#    'volatility_pct': 46.030715926634585,
#    'max_drawdown_pct': 11.053726583720715,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 66.85646633974042,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.008205,
#    'duration': 0.008205,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(24),
#     'sell_sma': np.int64(36),
#     'position_size_pct': 0.9910062740283949}},
#   'sharpe_ratio': 16.054781777695652,
#   'calmar_ratio': 66.85646633974042,
#   'total_return': 0.6889729255017031,
#   'annual_return': 7.39013099273218,
#   'max_drawdown': 0.11053726583720716,
#   'volatility': 0.46030715926634586,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 16889729.25501703,
#   'success': True},
#  {'params': {'buy_sma': np.int64(28),
#    'sell_sma': np.int64(37),
#    'position_size_pct': 0.5618303480648932},
#   'result': {'sharpe_ratio': 8.82741236731488,
#    'total_return': 0.37819139787973666,
#    'annual_return': 2.675907117293021,
#    'volatility': 0.3031360727183269,
#    'max_drawdown': 0.0775365883547795,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 13781913.978797367,
#    'final_equity': 13781913.978797367,
#    'total_pnl': 3781913.978797367,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 37.81913978797367,
#    'annual_return_pct': 267.5907117293021,
#    'volatility_pct': 30.313607271832687,
#    'max_drawdown_pct': 7.75365883547795,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 34.51154060388927,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.010556,
#    'duration': 0.010556,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(28),
#     'sell_sma': np.int64(37),
#     'position_size_pct': 0.5618303480648932}},
#   'sharpe_ratio': 8.82741236731488,
#   'calmar_ratio': 34.51154060388927,
#   'total_return': 0.37819139787973666,
#   'annual_return': 2.675907117293021,
#   'max_drawdown': 0.0775365883547795,
#   'volatility': 0.3031360727183269,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 13781913.978797367,
#   'success': True},
#  {'params': {'buy_sma': np.int64(27),
#    'sell_sma': np.int64(36),
#    'position_size_pct': 0.8012596343400344},
#   'result': {'sharpe_ratio': 12.696149753394375,
#    'total_return': 0.5564155567494545,
#    'annual_return': 5.02156774412381,
#    'volatility': 0.3955189440626494,
#    'max_drawdown': 0.09745767428982754,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 15564155.567494545,
#    'final_equity': 15564155.567494545,
#    'total_pnl': 5564155.567494545,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 55.64155567494545,
#    'annual_return_pct': 502.15677441238097,
#    'volatility_pct': 39.55189440626494,
#    'max_drawdown_pct': 9.745767428982754,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 51.525626696059504,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.009409,
#    'duration': 0.009409,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(27),
#     'sell_sma': np.int64(36),
#     'position_size_pct': 0.8012596343400344}},
#   'sharpe_ratio': 12.696149753394375,
#   'calmar_ratio': 51.525626696059504,
#   'total_return': 0.5564155567494545,
#   'annual_return': 5.02156774412381,
#   'max_drawdown': 0.09745767428982754,
#   'volatility': 0.3955189440626494,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 15564155.567494545,
#   'success': True},
#  {'params': {'buy_sma': np.int64(26),
#    'sell_sma': np.int64(39),
#    'position_size_pct': 0.8995803698371436},
#   'result': {'sharpe_ratio': 10.586586113240099,
#    'total_return': 0.52635867825615,
#    'annual_return': 4.563392525469147,
#    'volatility': 0.43105421111740133,
#    'max_drawdown': 0.10562040769398676,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 15263586.7825615,
#    'final_equity': 15263586.7825615,
#    'total_pnl': 5263586.7825615,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 52.635867825615,
#    'annual_return_pct': 456.3392525469147,
#    'volatility_pct': 43.105421111740135,
#    'max_drawdown_pct': 10.562040769398676,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 43.205594686688116,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.009801,
#    'duration': 0.009801,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(26),
#     'sell_sma': np.int64(39),
#     'position_size_pct': 0.8995803698371436}},
#   'sharpe_ratio': 10.586586113240099,
#   'calmar_ratio': 43.205594686688116,
#   'total_return': 0.52635867825615,
#   'annual_return': 4.563392525469147,
#   'max_drawdown': 0.10562040769398676,
#   'volatility': 0.43105421111740133,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 15263586.7825615,
#   'success': True},
#  {'params': {'buy_sma': np.int64(26),
#    'sell_sma': np.int64(39),
#    'position_size_pct': 0.8731155496761621},
#   'result': {'sharpe_ratio': 10.294583331967315,
#    'total_return': 0.5108922079269184,
#    'annual_return': 4.338130813070984,
#    'volatility': 0.42139935859278327,
#    'max_drawdown': 0.10363893537804436,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 15108922.079269184,
#    'final_equity': 15108922.079269184,
#    'total_pnl': 5108922.079269184,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 51.08922079269183,
#    'annual_return_pct': 433.81308130709846,
#    'volatility_pct': 42.139935859278324,
#    'max_drawdown_pct': 10.363893537804437,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 41.858118256876715,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.009863,
#    'duration': 0.009863,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(26),
#     'sell_sma': np.int64(39),
#     'position_size_pct': 0.8731155496761621}},
#   'sharpe_ratio': 10.294583331967315,
#   'calmar_ratio': 41.858118256876715,
#   'total_return': 0.5108922079269184,
#   'annual_return': 4.338130813070984,
#   'max_drawdown': 0.10363893537804436,
#   'volatility': 0.42139935859278327,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 15108922.079269184,
#   'success': True},
#  {'params': {'buy_sma': np.int64(26),
#    'sell_sma': np.int64(39),
#    'position_size_pct': 0.8671987711877835},
#   'result': {'sharpe_ratio': 10.205870492651597,
#    'total_return': 0.5068691424063427,
#    'annual_return': 4.280680571998225,
#    'volatility': 0.4194331659489888,
#    'max_drawdown': 0.10322724137903101,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 15068691.424063427,
#    'final_equity': 15068691.424063427,
#    'total_pnl': 5068691.424063427,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 50.68691424063427,
#    'annual_return_pct': 428.06805719982253,
#    'volatility_pct': 41.943316594898874,
#    'max_drawdown_pct': 10.322724137903101,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 41.468516593215654,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.008272,
#    'duration': 0.008272,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(26),
#     'sell_sma': np.int64(39),
#     'position_size_pct': 0.8671987711877835}},
#   'sharpe_ratio': 10.205870492651597,
#   'calmar_ratio': 41.468516593215654,
#   'total_return': 0.5068691424063427,
#   'annual_return': 4.280680571998225,
#   'max_drawdown': 0.10322724137903101,
#   'volatility': 0.4194331659489888,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 15068691.424063427,
#   'success': True},
#  {'params': {'buy_sma': np.int64(26),
#    'sell_sma': np.int64(39),
#    'position_size_pct': 0.86487599697244},
#   'result': {'sharpe_ratio': 10.177524688028381,
#    'total_return': 0.5054379305029973,
#    'annual_return': 4.260355354520292,
#    'volatility': 0.4186042760998323,
#    'max_drawdown': 0.10305521726663892,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 15054379.305029973,
#    'final_equity': 15054379.305029973,
#    'total_pnl': 5054379.305029973,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 50.54379305029973,
#    'annual_return_pct': 426.0355354520292,
#    'volatility_pct': 41.86042760998323,
#    'max_drawdown_pct': 10.305521726663892,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 41.3405111116044,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.008824,
#    'duration': 0.008824,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(26),
#     'sell_sma': np.int64(39),
#     'position_size_pct': 0.86487599697244}},
#   'sharpe_ratio': 10.177524688028381,
#   'calmar_ratio': 41.3405111116044,
#   'total_return': 0.5054379305029973,
#   'annual_return': 4.260355354520292,
#   'max_drawdown': 0.10305521726663892,
#   'volatility': 0.4186042760998323,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 15054379.305029973,
#   'success': True},
#  {'params': {'buy_sma': np.int64(26),
#    'sell_sma': np.int64(39),
#    'position_size_pct': 0.8632485342419922},
#   'result': {'sharpe_ratio': 10.16473860798956,
#    'total_return': 0.5045990405135165,
#    'annual_return': 4.248469377885949,
#    'volatility': 0.4179614982471483,
#    'max_drawdown': 0.1029236803556653,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 15045990.405135164,
#    'final_equity': 15045990.405135164,
#    'total_pnl': 5045990.405135164,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 50.45990405135164,
#    'annual_return_pct': 424.8469377885949,
#    'volatility_pct': 41.79614982471483,
#    'max_drawdown_pct': 10.29236803556653,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 41.27786106370124,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.010459,
#    'duration': 0.010459,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(26),
#     'sell_sma': np.int64(39),
#     'position_size_pct': 0.8632485342419922}},
#   'sharpe_ratio': 10.16473860798956,
#   'calmar_ratio': 41.27786106370124,
#   'total_return': 0.5045990405135165,
#   'annual_return': 4.248469377885949,
#   'max_drawdown': 0.1029236803556653,
#   'volatility': 0.4179614982471483,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 15045990.405135164,
#   'success': True},
#  {'params': {'buy_sma': np.int64(26),
#    'sell_sma': np.int64(39),
#    'position_size_pct': 0.8618024727754469},
#   'result': {'sharpe_ratio': 10.18003961706485,
#    'total_return': 0.504474931218311,
#    'annual_return': 4.246712631247425,
#    'volatility': 0.41716071754069006,
#    'max_drawdown': 0.10276577943073047,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 15044749.31218311,
#    'final_equity': 15044749.31218311,
#    'total_pnl': 5044749.31218311,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 50.4474931218311,
#    'annual_return_pct': 424.67126312474244,
#    'volatility_pct': 41.716071754069006,
#    'max_drawdown_pct': 10.276577943073047,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 41.32419035570038,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.004853,
#    'duration': 0.004853,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(26),
#     'sell_sma': np.int64(39),
#     'position_size_pct': 0.8618024727754469}},
#   'sharpe_ratio': 10.18003961706485,
#   'calmar_ratio': 41.32419035570038,
#   'total_return': 0.504474931218311,
#   'annual_return': 4.246712631247425,
#   'max_drawdown': 0.10276577943073047,
#   'volatility': 0.41716071754069006,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 15044749.31218311,
#   'success': True},
#  {'params': {'buy_sma': np.int64(26),
#    'sell_sma': np.int64(39),
#    'position_size_pct': 0.8603376067777699},
#   'result': {'sharpe_ratio': 10.15280499172252,
#    'total_return': 0.5033526820848031,
#    'annual_return': 4.230847491507704,
#    'volatility': 0.4167171037912253,
#    'max_drawdown': 0.10267129266180823,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 15033526.820848031,
#    'final_equity': 15033526.820848031,
#    'total_pnl': 5033526.820848031,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 50.33526820848031,
#    'annual_return_pct': 423.0847491507704,
#    'volatility_pct': 41.67171037912253,
#    'max_drawdown_pct': 10.267129266180824,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 41.20769673606631,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.008045,
#    'duration': 0.008045,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(26),
#     'sell_sma': np.int64(39),
#     'position_size_pct': 0.8603376067777699}},
#   'sharpe_ratio': 10.15280499172252,
#   'calmar_ratio': 41.20769673606631,
#   'total_return': 0.5033526820848031,
#   'annual_return': 4.230847491507704,
#   'max_drawdown': 0.10267129266180823,
#   'volatility': 0.4167171037912253,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 15033526.820848031,
#   'success': True},
#  {'params': {'buy_sma': np.int64(26),
#    'sell_sma': np.int64(39),
#    'position_size_pct': 0.8587307321505573},
#   'result': {'sharpe_ratio': 10.144075747752133,
#    'total_return': 0.5026145500530954,
#    'annual_return': 4.220432309467802,
#    'volatility': 0.4160489742402628,
#    'max_drawdown': 0.10253506589768144,
#    'total_trades': 1,
#    'winning_trades': 0,
#    'losing_trades': 0,
#    'win_rate': 0.0,
#    'avg_win': 0.0,
#    'avg_loss': 0.0,
#    'profit_factor': 0.0,
#    'final_portfolio_value': 15026145.500530954,
#    'final_equity': 15026145.500530954,
#    'total_pnl': 5026145.500530954,
#    'initial_capital': 10000000.0,
#    'total_return_pct': 50.26145500530954,
#    'annual_return_pct': 422.0432309467802,
#    'volatility_pct': 41.604897424026284,
#    'max_drawdown_pct': 10.253506589768143,
#    'win_rate_pct': 0.0,
#    'calmar_ratio': 41.160867967640684,
#    'sortino_ratio': 0.0,
#    'execution_time': 0.007458,
#    'duration': 0.007458,
#    'period': '2024-01-01 ~ 2024-03-31',
#    'start_date': '2024-01-01',
#    'end_date': '2024-03-31',
#    'success': True,
#    'params': {'buy_sma': np.int64(26),
#     'sell_sma': np.int64(39),
#     'position_size_pct': 0.8587307321505573}},
#   'sharpe_ratio': 10.144075747752133,
#   'calmar_ratio': 41.160867967640684,
#   'total_return': 0.5026145500530954,
#   'annual_return': 4.220432309467802,
#   'max_drawdown': 0.10253506589768144,
#   'volatility': 0.4160489742402628,
#   'win_rate': 0.0,
#   'profit_factor': 0.0,
#   'total_trades': 1,
#   'final_equity': 15026145.500530954,
#   'success': True}]
